# %%
import pandas as pd

# %%
df=pd.read_csv("data/filteredPredData.csv")
df
# Out:
#           Date Matched Keywords Prediction
# 0     8/4/2020            Trump   Negative
# 1     8/4/2020            Trump   Positive
# 2     8/4/2020            Trump   Negative
# 3     8/4/2020            Trump   Negative
# 4     8/4/2020            Trump   Negative
# ..         ...              ...        ...
# 700  8/10/2020            Trump   Positive
# 701  8/10/2020            Trump   Positive
# 702  8/10/2020            Biden   Positive
# 703  8/10/2020            Trump   Positive
# 704  8/10/2020            Trump   Positive
#
# [705 rows x 3 columns]

# %%
df_new=df.groupby(["Matched Keywords","Date", "Prediction"]).count()
type(df_new)
df_new
# df.to_json(orient="records")
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Biden, 8/10/2020, Negative), (Biden, 8/10/2020, Neutral), (Biden, 8/10/2020, Positive), (Biden, 8/4/2020, Negative), (Biden, 8/4/2020, Neutral), (Biden, 8/4/2020, Positive), (Biden, 8/5/2020, Negative), (Biden, 8/5/2020, Neutral), (Biden, 8/5/2020, Positive), (Biden, 8/6/2020, Negative), (Biden, 8/6/2020, Neutral), (Biden, 8/6/2020, Positive), (Biden, 8/7/2020, Negative), (Biden, 8/7/2020, Neutral), (Biden, 8/7/2020, Positive), (Biden, 8/8/2020, Negative), (Biden, 8/8/2020, Neutral), (Biden, 8/8/2020, Positive), (Biden, 8/9/2020, Neutral), (Biden, 8/9/2020, Positive), (Trump, 8/10/2020, Negative), (Trump, 8/10/2020, Neutral), (Trump, 8/10/2020, Positive), (Trump, 8/4/2020, Negative), (Trump, 8/4/2020, Neutral), (Trump, 8/4/2020, Positive), (Trump, 8/5/2020, Negative), (Trump, 8/5/2020, Neutral), (Trump, 8/5/2020, Positive), (Trump, 8/6/2020, Negative), (Trump, 8/6/2020, Neutral), (Trump, 8/6/2020, Positive), (Trump, 8/7/2020, Negative), (Trump, 8/7/2020, Neutral), (Trump, 8/7/2020, Positive), (Trump, 8/8/2020, Negative), (Trump, 8/8/2020, Neutral), (Trump, 8/8/2020, Positive), (Trump, 8/9/2020, Negative), (Trump, 8/9/2020, Neutral), (Trump, 8/9/2020, Positive)]

# %%
df=df.drop(["Favorite", "predTweet", "CleanedTweet", "Source"],axis=1)

# %%
trump_df=df.loc[df["Matched Keywords"]=="Trump"]
trump_df

# %%
pos_trump_df=trump_df.loc[trump_df["Prediction"]=="Positive"]
neg_trump_df=trump_df.loc[trump_df["Prediction"]=="Negative"]
neu_trump_df=trump_df.loc[trump_df["Prediction"]=="Neutral"]
neu_trump_df

# %%
biden_df=df.loc[df["Matched Keywords"]=="Biden"]

# %%
pos_biden_df=biden_df.loc[biden_df["Prediction"]=="Positive"]
neg_biden_df=biden_df.loc[biden_df["Prediction"]=="Negative"]
neu_biden_df=biden_df.loc[biden_df["Prediction"]=="Neutral"]
neu_biden_df
